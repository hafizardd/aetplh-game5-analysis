# %%
import sys
import json
from bs4 import BeautifulSoup
import requests

import time

# %%
sys.path.append('../youtube-livechat-scraper')

# %%
from livechat_scraper.scrapers import livechat_scraper
from livechat_scraper.constants import scraper_constants as sCons

# %%
video_url = "https://www.youtube.com/watch?v=cQIz9A5S2jU"

scraper = livechat_scraper.LiveChatScraper(
            video_url,
            start_time="3:25:30",  
            end_time="3:52:40"     
        )

# %%
scraper.scrape()
scraper.write_to_file(sCons.OUTPUT_JSON, "timeRange_"+scraper.output_filename, output_path="../data/raw")
# Out:
# Beginning livechat scraping from 3:25:30 to 3:52:40
# progress: 99.82% (at 3:52:37)
# scraping completed - collected 16864 messages
